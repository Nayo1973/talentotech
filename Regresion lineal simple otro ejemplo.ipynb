# %%
value_inversion en publicidad_list = [5000, 5570, 4350, 7900, 6800, 5400, 6900, 3900, 4200,5780]
value_ventas_list = [16000, 189380, 139200, 260700, 217600, 183600, 234600, 136500, 234600, 136500, 138600, 202300]
data= {"inversion en publicidad": value_inversion en publicidad_list, "y": value_ventas_list}
df = pd.DataFrame(data)
df
# Out:
#   File "/tmp/ipykernel_271/1431521505.py", line 1
#     value_inversion en publicidad_list = [5000, 5570, 4350, 7900, 6800, 5400, 6900, 3900, 4200,5780]
#                     ^
# SyntaxError: invalid syntax
